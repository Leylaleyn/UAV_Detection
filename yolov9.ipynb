# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !git clone https://github.com/SkalskiP/yolov9.git
# %cd yolov9
# !pip install -r requirements.txt -q
# Out:
# Cloning into 'yolov9'...
# remote: Enumerating objects: 325, done.
# remote: Counting objects: 100% (218/218), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 325 (delta 159), reused 156 (delta 156), pack-reused 107
# Receiving objects: 100% (325/325), 2.23 MiB | 36.91 MiB/s, done.
# Resolving deltas: 100% (165/165), done.
# /content/yolov9
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 36.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 68.7 MB/s eta 0:00:00

# %%
# !pip install -q roboflow
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 3.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 15.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 26.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 9.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 32.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.2 MB/s eta 0:00:00
# WARNING: The candidate selected for download or install is a yanked version: 'opencv-python-headless' candidate (version 4.8.0.74 at https://files.pythonhosted.org/packages/76/02/f128517f3ade4bb5f71e2afd8461dba70e3f466ce745fa1fd1fade9ad1b7/opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from https://pypi.org/simple/opencv-python-headless/) (requires-python:>=3.6))
# Reason for being yanked: deprecated, use 4.8.0.76

# %%
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-e.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-e.pt

# %%
# !ls -la {HOME}/weights
# Out:
# total 402444
# drwxr-xr-x 2 root root      4096 Jun 19 13:22 .
# drwxr-xr-x 1 root root      4096 Jun 19 13:22 ..
# -rw-r--r-- 1 root root  51508261 Feb 18 12:36 gelan-c.pt
# -rw-r--r-- 1 root root 117203713 Feb 18 12:36 gelan-e.pt
# -rw-r--r-- 1 root root 103153312 Feb 18 12:36 yolov9-c.pt
# -rw-r--r-- 1 root root 140217688 Feb 18 12:36 yolov9-e.pt

# %%
# %cd {HOME}/yolov9
# Out:
# /content/yolov9

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="rC3hDvkO3tP9sZI8ZnPA")
project = rf.workspace("armed-uav-detection").project("armed_uav")
version = project.version(1)
dataset = version.download("yolov9")
# Out:
# Requirement already satisfied: roboflow in /usr/local/lib/python3.10/dist-packages (1.1.32)
# Requirement already satisfied: certifi==2023.7.22 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2023.7.22)
# Requirement already satisfied: chardet==4.0.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.0.0)
# Requirement already satisfied: cycler==0.10.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.10.0)
# Requirement already satisfied: idna==2.10 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.10)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.25.2)
# Requirement already satisfied: opencv-python-headless==4.8.0.74 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.8.0.74)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (9.4.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.0.7)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.66.4)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.1)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: python-magic in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.4.27)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.2.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.53.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (3.3.2)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Armed_UAV-1 to yolov9:: 100%|██████████| 23632/23632 [00:02<00:00, 9025.73it/s]
# Extracting Dataset Version Zip to Armed_UAV-1 in yolov9:: 100%|██████████| 1052/1052 [00:00<00:00, 6934.67it/s]

# %%
# %cd {HOME}/yolov9

# !python train.py \
--batch 4 --epochs 30 --img 640 --device 0 --min-items 0 --close-mosaic 15 \
--data /content/yolov9/Armed_UAV-1/data.yaml \
--weights {HOME}/weights/gelan-c.pt \
--cfg models/detect/gelan-c.yaml \
--hyp hyp.scratch-high.yaml
# Out:
# /content/yolov9
# 2024-06-19 13:22:39.316027: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-19 13:22:39.368619: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-19 13:22:39.368676: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-19 13:22:39.370227: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-19 13:22:39.378204: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-19 13:22:40.689276: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# train: weights=/content/weights/gelan-c.pt, cfg=models/detect/gelan-c.yaml, data=/content/yolov9/Armed_UAV-1/data.yaml, hyp=hyp.scratch-high.yaml, epochs=30, batch_size=4, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=15, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, cls_pw=1.0, dfl=1.5, obj_pw=1.0, iou_t=0.2, anchor_t=5.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.9, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.15, copy_paste=0.3
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLO 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLO 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 102MB/s]
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      1856  models.common.Conv                      [3, 64, 3, 2]
#   1                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   2                -1  1    212864  models.common.RepNCSPELAN4              [128, 256, 128, 64, 1]
#   3                -1  1    164352  models.common.ADown                     [256, 256]
#   4                -1  1    847616  models.common.RepNCSPELAN4              [256, 512, 256, 128, 1]
#   5                -1  1    656384  models.common.ADown                     [512, 512]
#   6                -1  1   2857472  models.common.RepNCSPELAN4              [512, 512, 512, 256, 1]
#   7                -1  1    656384  models.common.ADown                     [512, 512]
#   8                -1  1   2857472  models.common.RepNCSPELAN4              [512, 512, 512, 256, 1]
#   9                -1  1    656896  models.common.SPPELAN                   [512, 512, 256]
#  10                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  11           [-1, 6]  1         0  models.common.Concat                    [1]
#  12                -1  1   3119616  models.common.RepNCSPELAN4              [1024, 512, 512, 256, 1]
#  13                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  14           [-1, 4]  1         0  models.common.Concat                    [1]
#  15                -1  1    912640  models.common.RepNCSPELAN4              [1024, 256, 256, 128, 1]
#  16                -1  1    164352  models.common.ADown                     [256, 256]
#  17          [-1, 12]  1         0  models.common.Concat                    [1]
#  18                -1  1   2988544  models.common.RepNCSPELAN4              [768, 512, 512, 256, 1]
#  19                -1  1    656384  models.common.ADown                     [512, 512]
#  20           [-1, 9]  1         0  models.common.Concat                    [1]
#  21                -1  1   3119616  models.common.RepNCSPELAN4              [1024, 512, 512, 256, 1]
#  22      [15, 18, 21]  1   5491411  models.yolo.DDetect                     [1, [256, 512, 512]]
# gelan-c summary: 621 layers, 25437843 parameters, 25437827 gradients, 103.2 GFLOPs
#
# Transferred 931/937 items from /content/weights/gelan-c.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 154 weight(decay=0.0), 161 weight(decay=0.0005), 160 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# train: Scanning /content/yolov9/Armed_UAV-1/train/labels... 364 images, 0 backgrounds, 0 corrupt: 100% 364/364 [00:00<00:00, 6999.48it/s]
# train: New cache created: /content/yolov9/Armed_UAV-1/train/labels.cache
# val: Scanning /content/yolov9/Armed_UAV-1/valid/labels... 104 images, 0 backgrounds, 0 corrupt: 100% 104/104 [00:00<00:00, 3547.36it/s]
# val: New cache created: /content/yolov9/Armed_UAV-1/valid/labels.cache
# Plotting labels to runs/train/exp/labels.jpg...
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to runs/train/exp
# Starting training for 30 epochs...
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        0/29      3.08G      1.875       2.92      1.734         15        640: 100% 91/91 [00:23<00:00,  3.80it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:02<00:00,  4.41it/s]
#                    all        104        106        0.9      0.651      0.814      0.421
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/29      3.25G      1.701      1.747      1.623         12        640: 100% 91/91 [00:13<00:00,  6.68it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:01<00:00,  8.54it/s]
#                    all        104        106      0.614      0.629      0.684      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/29      3.25G      1.663      2.209      1.598         10        640: 100% 91/91 [00:13<00:00,  6.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:01<00:00,  8.64it/s]
#                    all        104        106      0.772      0.651      0.693      0.393
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/29      3.25G      1.634      2.256      1.606         13        640: 100% 91/91 [00:13<00:00,  6.76it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:01<00:00,  8.58it/s]
#                    all        104        106      0.882      0.636      0.797      0.458
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/29      3.25G      1.618      1.634      1.634         11        640: 100% 91/91 [00:13<00:00,  6.74it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:01<00:00,  8.54it/s]
#                    all        104        106      0.808      0.698      0.784      0.439
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/29      3.25G      1.633      1.513      1.615         10        640: 100% 91/91 [00:13<00:00,  6.79it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:01<00:00,  8.60it/s]
#                    all        104        106      0.705      0.745      0.784      0.405
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/29      3.25G      1.655      1.613      1.615          4        640: 100% 91/91 [00:13<00:00,  6.73it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:01<00:00,  8.54it/s]
#                    all        104        106      0.707      0.651      0.714      0.364
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/29      3.25G      1.707       1.61      1.657         11        640: 100% 91/91 [00:13<00:00,  6.70it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:01<00:00,  8.42it/s]
#                    all        104        106      0.867      0.675      0.778      0.426
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/29      3.25G      1.719      1.558      1.648         10        640: 100% 91/91 [00:13<00:00,  6.73it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:01<00:00,  8.45it/s]
#                    all        104        106      0.834      0.712      0.806      0.433
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/29      3.25G      1.676       1.46      1.656          5        640: 100% 91/91 [00:13<00:00,  6.69it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:01<00:00,  8.47it/s]
#                    all        104        106      0.758      0.689      0.788       0.44
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/29      3.25G      1.678      1.412      1.671         10        640: 100% 91/91 [00:13<00:00,  6.70it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:01<00:00,  8.20it/s]
#                    all        104        106      0.781      0.708      0.796      0.434
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/29      3.25G      1.679       1.52      1.683          5        640: 100% 91/91 [00:13<00:00,  6.68it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:01<00:00,  8.48it/s]
#                    all        104        106       0.84      0.849      0.899      0.469
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/29      3.25G       1.69      1.359       1.68          5        640: 100% 91/91 [00:13<00:00,  6.79it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:01<00:00,  8.50it/s]
#                    all        104        106      0.815       0.83       0.86      0.501
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/29      3.25G      1.648      1.355      1.636         12        640: 100% 91/91 [00:13<00:00,  6.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:01<00:00,  8.58it/s]
#                    all        104        106      0.825      0.754      0.839      0.461
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/29      3.25G      1.619      1.382      1.622          9        640: 100% 91/91 [00:13<00:00,  6.64it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:01<00:00,  8.47it/s]
#                    all        104        106      0.779      0.821      0.874      0.488
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/29      3.25G      1.539      1.179      1.689          4        640: 100% 91/91 [00:13<00:00,  6.84it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:01<00:00,  8.19it/s]
#                    all        104        106      0.862      0.764      0.893      0.493
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/29      3.25G      1.557      1.124      1.668          4        640: 100% 91/91 [00:13<00:00,  6.77it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:01<00:00,  8.52it/s]
#                    all        104        106      0.788      0.792      0.834      0.472
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/29      3.25G      1.534      1.132      1.662          4        640: 100% 91/91 [00:13<00:00,  6.82it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:01<00:00,  8.59it/s]
#                    all        104        106      0.932      0.783      0.901      0.513
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/29      3.25G      1.452     0.9861      1.584          4        640: 100% 91/91 [00:13<00:00,  6.83it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:01<00:00,  8.66it/s]
#                    all        104        106      0.812       0.84       0.89      0.517
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/29      3.25G      1.524     0.9479       1.61          4        640: 100% 91/91 [00:13<00:00,  6.84it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:01<00:00,  8.59it/s]
#                    all        104        106      0.805       0.78      0.863      0.462
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/29      3.25G      1.468     0.9682      1.642          4        640: 100% 91/91 [00:13<00:00,  6.78it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:01<00:00,  8.64it/s]
#                    all        104        106      0.794      0.915      0.901      0.518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/29      3.25G      1.526     0.9584      1.632          4        640: 100% 91/91 [00:13<00:00,  6.80it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:01<00:00,  8.63it/s]
#                    all        104        106      0.827       0.83      0.898      0.515
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/29      3.25G      1.447     0.9293      1.568          4        640: 100% 91/91 [00:13<00:00,  6.73it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:01<00:00,  8.52it/s]
#                    all        104        106      0.901      0.811      0.893      0.539
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/29      3.25G      1.369     0.8305      1.546          4        640: 100% 91/91 [00:13<00:00,  6.78it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:01<00:00,  8.51it/s]
#                    all        104        106      0.888      0.822      0.898      0.555
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/29      3.25G      1.364     0.8813      1.534          4        640: 100% 91/91 [00:13<00:00,  6.84it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:01<00:00,  8.34it/s]
#                    all        104        106      0.926      0.811      0.921      0.551
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/29      3.25G      1.318     0.7975      1.476          4        640: 100% 91/91 [00:13<00:00,  6.61it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:01<00:00,  8.64it/s]
#                    all        104        106      0.957      0.831      0.942       0.58
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/29      3.25G      1.351     0.7849      1.527          4        640: 100% 91/91 [00:13<00:00,  6.82it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:01<00:00,  8.57it/s]
#                    all        104        106      0.924      0.925      0.963      0.567
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/29      3.25G      1.343     0.7761      1.496          4        640: 100% 91/91 [00:13<00:00,  6.85it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:01<00:00,  8.65it/s]
#                    all        104        106      0.941      0.896      0.964      0.573
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/29      3.25G      1.263     0.7342      1.441          4        640: 100% 91/91 [00:13<00:00,  6.84it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:01<00:00,  8.53it/s]
#                    all        104        106      0.905      0.906      0.965      0.582
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/29      3.25G      1.262     0.7133       1.41          4        640: 100% 91/91 [00:13<00:00,  6.77it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:01<00:00,  8.66it/s]
#                    all        104        106      0.914      0.934      0.967      0.604
#
# 30 epochs completed in 0.141 hours.
# Optimizer stripped from runs/train/exp/weights/last.pt, saved as runs/train/exp/weights/last_striped.pt, 51.5MB
# Optimizer stripped from runs/train/exp/weights/best.pt, saved as runs/train/exp/weights/best_striped.pt, 51.5MB
#
# Validating runs/train/exp/weights/best.pt...
# Fusing layers...
# gelan-c summary: 467 layers, 25411731 parameters, 0 gradients, 102.5 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:02<00:00,  5.80it/s]
#                    all        104        106      0.923      0.934      0.969      0.602
# Results saved to runs/train/exp

# %%
# !ls {HOME}/yolov9/runs/train/exp/
# Out:
# confusion_matrix.png				    PR_curve.png	   val_batch0_pred.jpg
# events.out.tfevents.1718803361.6acab97d63e7.2354.0  R_curve.png		   val_batch1_labels.jpg
# F1_curve.png					    results.csv		   val_batch1_pred.jpg
# hyp.yaml					    results.png		   val_batch2_labels.jpg
# labels_correlogram.jpg				    train_batch0.jpg	   val_batch2_pred.jpg
# labels.jpg					    train_batch1.jpg	   weights
# opt.yaml					    train_batch2.jpg
# P_curve.png					    val_batch0_labels.jpg

# %%
from IPython.display import Image

Image(filename=f"{HOME}/yolov9/runs/train/exp/results.png", width=1000)

# %%
from IPython.display import Image

Image(filename=f"{HOME}/yolov9/runs/train/exp/val_batch0_pred.jpg", width=1000)

# %%
Image(filename=f"{HOME}/yolov9/runs/train/exp/val_batch0_pred.jpg", width=1000)

# %% [markdown]
# VALIDATE CUSTOM MODEL

# %%
# %cd {HOME}/yolov9

# !python val.py \
--img 640 --batch 32 --conf 0.001 --iou 0.7 --device 0 \
--data {dataset.location}/data.yaml \
--weights {HOME}/yolov9/runs/train/exp/weights/best.pt
# Out:
# /content/yolov9
# val: data=/content/yolov9/Armed_UAV-1/data.yaml, weights=['/content/yolov9/runs/train/exp/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.7, max_det=300, task=val, device=0, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False, min_items=0
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25411731 parameters, 0 gradients, 102.5 GFLOPs
# val: Scanning /content/yolov9/Armed_UAV-1/valid/labels.cache... 104 images, 0 backgrounds, 0 corrupt: 100% 104/104 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:04<00:00,  1.24s/it]
#                    all        104        106      0.924      0.934      0.969      0.606
# Speed: 1.2ms pre-process, 23.6ms inference, 7.3ms NMS per image at shape (32, 3, 640, 640)
# Results saved to runs/val/exp

# %% [markdown]
# ## Inference with Custom Model

# %%
# !python detect.py \
--img 1280 --conf 0.1 --device 0 \
--weights {HOME}/yolov9/runs/train/exp/weights/best.pt \
--source {dataset.location}/test/images
# Out:
# detect: weights=['/content/yolov9/runs/train/exp/weights/best.pt'], source=/content/yolov9/Armed_UAV-1/test/images, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25411731 parameters, 0 gradients, 102.5 GFLOPs
# image 1/52 /content/yolov9/Armed_UAV-1/test/images/113_png_jpg.rf.b7b88096f64f84215d2ac1869d50dfcf.jpg: 1280x1280 6 0s, 35.2ms
# image 2/52 /content/yolov9/Armed_UAV-1/test/images/115_png_jpg.rf.ba4bcac34d8d012c5bb33fc16d774bb3.jpg: 1280x1280 1 0, 35.8ms
# image 3/52 /content/yolov9/Armed_UAV-1/test/images/118_png_jpg.rf.f08f00356cc822b773e3448c1a67d191.jpg: 1280x1280 2 0s, 36.1ms
# image 4/52 /content/yolov9/Armed_UAV-1/test/images/119_png_jpg.rf.078a59b1f6def9ddbe77c9da4fbcc782.jpg: 1280x1280 2 0s, 36.1ms
# image 5/52 /content/yolov9/Armed_UAV-1/test/images/119_png_jpg.rf.6ed89ce102c7cc4b112d002bda63106f.jpg: 1280x1280 1 0, 36.1ms
# image 6/52 /content/yolov9/Armed_UAV-1/test/images/119_png_jpg.rf.9d03722eb010489ede92d334f492c6f3.jpg: 1280x1280 (no detections), 35.8ms
# image 7/52 /content/yolov9/Armed_UAV-1/test/images/11_png_jpg.rf.42922cbd0b29a80f4672166ea4142730.jpg: 1280x1280 1 0, 36.0ms
# image 8/52 /content/yolov9/Armed_UAV-1/test/images/120_png_jpg.rf.d1ed91851145339f973628d2bfdefdc7.jpg: 1280x1280 (no detections), 36.0ms
# image 9/52 /content/yolov9/Armed_UAV-1/test/images/122_png_jpg.rf.065f117c92d826018ddb2216a50da17f.jpg: 1280x1280 (no detections), 36.1ms
# image 10/52 /content/yolov9/Armed_UAV-1/test/images/124_png_jpg.rf.1fd047380a90709cb5080c83065adc05.jpg: 1280x1280 1 0, 36.2ms
# image 11/52 /content/yolov9/Armed_UAV-1/test/images/133_png_jpg.rf.ae2a81a0b3856c885a12115a5314bd96.jpg: 1280x1280 1 0, 36.1ms
# image 12/52 /content/yolov9/Armed_UAV-1/test/images/134_png_jpg.rf.eb5074914d7f1dc7cc6aa540693809e9.jpg: 1280x1280 6 0s, 36.1ms
# image 13/52 /content/yolov9/Armed_UAV-1/test/images/138_png_jpg.rf.6c0efe8c43926a4f3703e2d97b6d4caa.jpg: 1280x1280 1 0, 35.8ms
# image 14/52 /content/yolov9/Armed_UAV-1/test/images/138_png_jpg.rf.920888eca55476398d251fe8ea0019f1.jpg: 1280x1280 1 0, 35.8ms
# image 15/52 /content/yolov9/Armed_UAV-1/test/images/141_png_jpg.rf.54ec7dbf84f8a3297d38023ea076b9da.jpg: 1280x1280 2 0s, 35.8ms
# image 16/52 /content/yolov9/Armed_UAV-1/test/images/143_png_jpg.rf.6c17dfb0b36d9180bf7f33664e5e8cee.jpg: 1280x1280 2 0s, 36.0ms
# image 17/52 /content/yolov9/Armed_UAV-1/test/images/146_png_jpg.rf.7697bdf0a9d2c8b50f6ea405d24a24b2.jpg: 1280x1280 1 0, 35.9ms
# image 18/52 /content/yolov9/Armed_UAV-1/test/images/166_png_jpg.rf.585aaa85ee9114f2e1c288328621ef02.jpg: 1280x1280 1 0, 36.1ms
# image 19/52 /content/yolov9/Armed_UAV-1/test/images/167_png_jpg.rf.7ab73b609438287a295f2c37ce75e2ee.jpg: 1280x1280 2 0s, 36.1ms
# image 20/52 /content/yolov9/Armed_UAV-1/test/images/175_png_jpg.rf.07e97b9b01b2b741d264c5119131354d.jpg: 1280x1280 3 0s, 36.0ms
# image 21/52 /content/yolov9/Armed_UAV-1/test/images/175_png_jpg.rf.255ff54c1735e70d1b2d88aa3bdc06d0.jpg: 1280x1280 3 0s, 35.8ms
# image 22/52 /content/yolov9/Armed_UAV-1/test/images/176_png_jpg.rf.d552c849094a8dd823014f1bde31174e.jpg: 1280x1280 3 0s, 36.0ms
# image 23/52 /content/yolov9/Armed_UAV-1/test/images/178_png_jpg.rf.a299e6524fe462e5b8925802c001245c.jpg: 1280x1280 1 0, 36.2ms
# image 24/52 /content/yolov9/Armed_UAV-1/test/images/182_png_jpg.rf.0312e96ca69986ffbf301e1406c7a01a.jpg: 1280x1280 3 0s, 36.2ms
# image 25/52 /content/yolov9/Armed_UAV-1/test/images/182_png_jpg.rf.8a4dc44e8e3481a6df1bf6745f5c7b66.jpg: 1280x1280 2 0s, 36.0ms
# image 26/52 /content/yolov9/Armed_UAV-1/test/images/196_png_jpg.rf.a5b28605ce5004004abe02a09b96a416.jpg: 1280x1280 1 0, 35.9ms
# image 27/52 /content/yolov9/Armed_UAV-1/test/images/199_png_jpg.rf.0f2df00bf029e0a808a0d760a0d1fd4e.jpg: 1280x1280 2 0s, 36.1ms
# image 28/52 /content/yolov9/Armed_UAV-1/test/images/1_png_jpg.rf.54a2311ab2ec219efd387d6d447358d7.jpg: 1280x1280 3 0s, 36.0ms
# image 29/52 /content/yolov9/Armed_UAV-1/test/images/200_png_jpg.rf.5a4ddff22c6dc67a1ddb2374a3e5e103.jpg: 1280x1280 1 0, 36.1ms
# image 30/52 /content/yolov9/Armed_UAV-1/test/images/21_png_jpg.rf.2ceb9853dba7dce9c24a53e029033632.jpg: 1280x1280 1 0, 36.3ms
# image 31/52 /content/yolov9/Armed_UAV-1/test/images/24_png_jpg.rf.ddd03d65ca9082da95dde6151bd8eb6d.jpg: 1280x1280 1 0, 36.2ms
# image 32/52 /content/yolov9/Armed_UAV-1/test/images/30_png_jpg.rf.3b3fcb466975855c6c6efdccb740edf2.jpg: 1280x1280 1 0, 36.0ms
# image 33/52 /content/yolov9/Armed_UAV-1/test/images/30_png_jpg.rf.4199c88a048052218e1a4058a1975bfa.jpg: 1280x1280 1 0, 36.1ms
# image 34/52 /content/yolov9/Armed_UAV-1/test/images/31_png_jpg.rf.0bb2846b865f93e6ed452ffb4e682674.jpg: 1280x1280 1 0, 36.0ms
# image 35/52 /content/yolov9/Armed_UAV-1/test/images/33_png_jpg.rf.b37287dd14411be9bb00137e642a8af2.jpg: 1280x1280 2 0s, 36.1ms
# image 36/52 /content/yolov9/Armed_UAV-1/test/images/35_png_jpg.rf.df1e2305cec43241a53ffb089f86c54b.jpg: 1280x1280 1 0, 36.0ms
# image 37/52 /content/yolov9/Armed_UAV-1/test/images/39_png_jpg.rf.9f25f3f2e2dd8358c53b09f011f1fc7a.jpg: 1280x1280 1 0, 36.0ms
# image 38/52 /content/yolov9/Armed_UAV-1/test/images/44_png_jpg.rf.9150116395aa3e5233337a773a7aa0d6.jpg: 1280x1280 1 0, 35.9ms
# image 39/52 /content/yolov9/Armed_UAV-1/test/images/46_png_jpg.rf.4a68d8f7097a814c34aa35995263ebfe.jpg: 1280x1280 2 0s, 35.9ms
# image 40/52 /content/yolov9/Armed_UAV-1/test/images/46_png_jpg.rf.792dd6f924cbf62d694c7b72beccd400.jpg: 1280x1280 1 0, 36.1ms
# image 41/52 /content/yolov9/Armed_UAV-1/test/images/51_png_jpg.rf.460cd820e2b1bbeef2a62698445a2187.jpg: 1280x1280 1 0, 36.1ms
# image 42/52 /content/yolov9/Armed_UAV-1/test/images/51_png_jpg.rf.872fa2ef31f09dc6b4b12a5482687d38.jpg: 1280x1280 2 0s, 36.1ms
# image 43/52 /content/yolov9/Armed_UAV-1/test/images/55_png_jpg.rf.bcce670cb40ab761bda0c404ee0e59f5.jpg: 1280x1280 2 0s, 35.8ms
# image 44/52 /content/yolov9/Armed_UAV-1/test/images/59_png_jpg.rf.9f01e9658fbe79e7b7c9f426b5970977.jpg: 1280x1280 6 0s, 36.1ms
# image 45/52 /content/yolov9/Armed_UAV-1/test/images/5_png_jpg.rf.51cf45928c674e63ac068c0f6871b083.jpg: 1280x1280 1 0, 36.1ms
# image 46/52 /content/yolov9/Armed_UAV-1/test/images/62_png_jpg.rf.78a5886b73d1fae2bc84ab6ad449c40d.jpg: 1280x1280 4 0s, 35.9ms
# image 47/52 /content/yolov9/Armed_UAV-1/test/images/71_png_jpg.rf.4fc1c15b2de2d1b6bbbbbaf062e86f61.jpg: 1280x1280 2 0s, 35.7ms
# image 48/52 /content/yolov9/Armed_UAV-1/test/images/78_png_jpg.rf.1b5a95f1ec30147c59fe804e32482ad6.jpg: 1280x1280 4 0s, 36.0ms
# image 49/52 /content/yolov9/Armed_UAV-1/test/images/8_png_jpg.rf.347be9b07b6f3cf8a9469bbb6934ca67.jpg: 1280x1280 1 0, 36.1ms
# image 50/52 /content/yolov9/Armed_UAV-1/test/images/97_png_jpg.rf.92adb37785a45a1703c5d97210bbad9d.jpg: 1280x1280 4 0s, 36.1ms
# image 51/52 /content/yolov9/Armed_UAV-1/test/images/99_png_jpg.rf.3499c8fe6ece41ef150462fea58cc025.jpg: 1280x1280 2 0s, 36.2ms
# image 52/52 /content/yolov9/Armed_UAV-1/test/images/99_png_jpg.rf.84fdb4eb70959021fd9fd90537b77866.jpg: 1280x1280 4 0s, 36.1ms
# Speed: 1.8ms pre-process, 36.0ms inference, 13.8ms NMS per image at shape (1, 3, 1280, 1280)
# Results saved to runs/detect/exp

# %%
import glob

from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/yolov9/runs/detect/exp/*.jpg')[:2]:
      display(Image(filename=image_path, width=200))

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil

# Dosyayı taşı
source_path = '/content/yolov9/runs'
target_path = '/content/drive/MyDrive/UAV_Detection'
shutil.move(source_path, target_path)
# Out:
# '/content/drive/MyDrive/UAV_Detection/runs'
